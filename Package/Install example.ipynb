# %% [markdown]
# #### An example about how to install our 'hierarchical_LDA' package

# %%
# %%bash
#
# pip install --index-url https://test.pypi.org/simple/ hierarchical_LDA
# Out:
# Looking in indexes: https://test.pypi.org/simple/
# ...
#   Running setup.py bdist_wheel for hierarchical-LDA: started
#   Running setup.py bdist_wheel for hierarchical-LDA: finished with status 'done'
#   Stored in directory: /home/jovyan/.cache/pip/wheels/69/df/47/c64b96515d041753345ac8ea3fcbf5c2a302a43da2b7a85b46
# Successfully built hierarchical-LDA
# ...

# %%
import hierarchical_LDA

# %%
corpus=[['a'],
 ['b', 'c', 'd'],
 ['e', 'f', 'a', 'c'],
 ['g', 'd', 'e', 'b', 'a'],
 ['a'],
 ['b', 'c', 'd'],
 ['e', 'f', 'a', 'c'],
 ['g', 'd', 'e', 'b', 'a']]

# %%
hlda=hierarchical_LDA.hierarchical_LDA(corpus,0.1,0.1,1,0.1,10,2)

# %%
hlda
# Out:
# ([[['b', 'c', 'd', 'g', 'd', 'b', 'a']],
#   [['a', 'c', 'b'], ['f', 'e', 'f', 'c'], ['e', 'e', 'a', 'b', 'c']]],
#  [[1], [3]])

# %%
hierarchical_LDA.tree_plot(hlda)
